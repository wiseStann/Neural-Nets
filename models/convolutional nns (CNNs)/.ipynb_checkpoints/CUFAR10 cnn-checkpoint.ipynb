# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-1.11.0-cp39-cp39-win_amd64.whl (157.9 MB)
# Requirement already satisfied: typing-extensions in c:\users\stann\anaconda3\lib\site-packages (from torch) (3.10.0.2)
# Installing collected packages: torch
# Successfully installed torch-1.11.0

# %%
# !pip install torchvision
# Out:
# Collecting torchvision
#   Downloading torchvision-0.12.0-cp39-cp39-win_amd64.whl (1.0 MB)
# Requirement already satisfied: typing-extensions in c:\users\stann\anaconda3\lib\site-packages (from torchvision) (3.10.0.2)
# Requirement already satisfied: numpy in c:\users\stann\anaconda3\lib\site-packages (from torchvision) (1.20.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\stann\anaconda3\lib\site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: requests in c:\users\stann\anaconda3\lib\site-packages (from torchvision) (2.26.0)
# Requirement already satisfied: torch==1.11.0 in c:\users\stann\anaconda3\lib\site-packages (from torchvision) (1.11.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\stann\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\stann\anaconda3\lib\site-packages (from requests->torchvision) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stann\anaconda3\lib\site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\stann\anaconda3\lib\site-packages (from requests->torchvision) (1.26.7)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.12.0

# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms

import numpy as np
import matplotlib.pyplot as plt
import os
import time

# %%
num_epochs = 30
num_classes = 10
batch_size = 100
learning_rate = 1e-3

# %%
def get_data(path, num_workers):
    train_data = torchvision.datasets.CIFAR10(root=path, train=True,
        transform=transforms.ToTensor(), download=True)
    test_data = torchvision.datasets.CIFAR10(root=path, train=False,
        transform=transforms.ToTensor())

    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, num_workers=2)
    test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, num_workers=2)
    return train_loader, test_loader


# All classes of images in dataset
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
train_data, test_data = get_data("data", 2)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data\cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting data\cifar-10-python.tar.gz to data

# %%
# Show the number of images equals to batch_size
def imshow(img):
    img = img / 2 + 0.3
    npimg = img.numpy()
    plt.figure(figsize=(8, 3))
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

# %%
# Checking out the dataset 
dataiter = iter(train_data)
images, labels = dataiter.next()
imshow(torchvision.utils.make_grid(images[:5]))
print("  ".join('%5s' % classes[labels[j]] for j in range(5)))
# Out:
#   cat   bird  plane   bird    car

# %%
class CNN(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        
        # Convolutional and pooling layers
        self.cl1 = self.create_conv_layer(3, 30)
        self.cl2 = self.create_conv_layer(30, 30)
        self.cl3 = self.create_conv_layer(30, 30)
        
        # Dropout and fully connected layers
        self.drop_out = nn.Dropout()
        self.fc1 = self.create_fc_layer(4 * 4 * 30, 300)
        self.fc2 = self.create_fc_layer(300, 350)
        self.fc3 = nn.Linear(350, num_classes)
    
    # Creation of convolutional block: convolutional layer, ReLU activation function,
    # 2d BatchNorming and MaxPooling
    def create_conv_layer(self, in_features, out_features):
        self.layer = nn.Sequential(
            nn.Conv2d(in_features, out_features, kernel_size=5, stride=1, padding=2),
            nn.ReLU(),
            nn.BatchNorm2d(out_features),
            nn.MaxPool2d(2, 2),
        )
        return self.layer
    
    # Creation of fully connected layer: Linear layer,
    # Tanh activation function and 1d BatchNorming
    def create_fc_layer(self, in_features, out_features):
        self.layer = nn.Sequential(
            nn.Linear(in_features, out_features),
            nn.ReLU(),
            nn.BatchNorm1d(out_features))
        return self.layer
    
    # Forward pass
    def forward(self, x):
        x = self.cl1(x)
        x = self.cl2(x)
        x = self.cl3(x)
        x = x.view(x.size(0), -1)
        x = self.drop_out(x)
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        return x

# %%
model = CNN()

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
losses = []

# Train our model
def train(model, epochs, learning_rate):
    start = time.time()
    total = len(train_data)
    for epoch in range(epochs):
        for i, (images, labels) in enumerate(train_data):
            images, labels = Variable(images), Variable(labels)
            
            outputs = model(images) # Forward pass
            loss = criterion(outputs, labels)
            losses.append(loss.item())

            optimizer.zero_grad() # Zero gradient value
            loss.backward() # Backward pass
            optimizer.step() # Update our weights
            
            # Visual information
            if (i+1) % 100 == 0:
                print (f"Epoch [{epoch+1}/{epochs}], Step [{i+1}/{total}], Loss: {round(loss.item(), 4)}")
    all_time = round((time.time() - start) / 60, 2)
    print(f"\nTime of training: {all_time} minutes")

# %%
# Test our model
def validate_model(model, data):
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in data:
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        
        if len(data) > 100:
            print(f"Accuracy of the model on train data: {round(correct / total * 100, 2)}%")
        elif len(data) == 100:
            print(f"Accuracy of the model on test data: {round(correct / total * 100, 2)}%")

# %% [markdown]
# ## Training

# %%
train(model, num_epochs, learning_rate)
# Out:
# Epoch [1/30], Step [100/500], Loss: 1.4788
# Epoch [1/30], Step [200/500], Loss: 1.225
# Epoch [1/30], Step [300/500], Loss: 1.2921
# Epoch [1/30], Step [400/500], Loss: 1.1882
# Epoch [1/30], Step [500/500], Loss: 0.9896
# Epoch [2/30], Step [100/500], Loss: 1.0927
# Epoch [2/30], Step [200/500], Loss: 1.2284
# Epoch [2/30], Step [300/500], Loss: 1.1305
# Epoch [2/30], Step [400/500], Loss: 1.0923
# Epoch [2/30], Step [500/500], Loss: 1.1268
# Epoch [3/30], Step [100/500], Loss: 0.839
# Epoch [3/30], Step [200/500], Loss: 1.1159
# Epoch [3/30], Step [300/500], Loss: 0.9017
# Epoch [3/30], Step [400/500], Loss: 1.1246
# Epoch [3/30], Step [500/500], Loss: 1.0292
# Epoch [4/30], Step [100/500], Loss: 0.8493
# Epoch [4/30], Step [200/500], Loss: 0.9105
# Epoch [4/30], Step [300/500], Loss: 0.8907
# Epoch [4/30], Step [400/500], Loss: 0.8464
# Epoch [4/30], Step [500/500], Loss: 1.008
# Epoch [5/30], Step [100/500], Loss: 0.8519
# Epoch [5/30], Step [200/500], Loss: 0.9181
# Epoch [5/30], Step [300/500], Loss: 0.7705
# Epoch [5/30], Step [400/500], Loss: 0.9817
# Epoch [5/30], Step [500/500], Loss: 0.9473
# Epoch [6/30], Step [100/500], Loss: 0.6664
# Epoch [6/30], Step [200/500], Loss: 0.9181
# Epoch [6/30], Step [300/500], Loss: 0.7783
# Epoch [6/30], Step [400/500], Loss: 0.7686
# Epoch [6/30], Step [500/500], Loss: 0.6417
# Epoch [7/30], Step [100/500], Loss: 0.7399
# Epoch [7/30], Step [200/500], Loss: 0.8014
# Epoch [7/30], Step [300/500], Loss: 0.5459
# Epoch [7/30], Step [400/500], Loss: 0.7291
# Epoch [7/30], Step [500/500], Loss: 0.8572
# Epoch [8/30], Step [100/500], Loss: 0.6194
# Epoch [8/30], Step [200/500], Loss: 0.6864
# Epoch [8/30], Step [300/500], Loss: 0.7104
# Epoch [8/30], Step [400/500], Loss: 0.7779
# Epoch [8/30], Step [500/500], Loss: 0.7529
# Epoch [9/30], Step [100/500], Loss: 0.8182
# Epoch [9/30], Step [200/500], Loss: 0.6703
# Epoch [9/30], Step [300/500], Loss: 0.6277
# Epoch [9/30], Step [400/500], Loss: 0.6983
# Epoch [9/30], Step [500/500], Loss: 0.6488
# Epoch [10/30], Step [100/500], Loss: 0.673
# Epoch [10/30], Step [200/500], Loss: 0.6233
# Epoch [10/30], Step [300/500], Loss: 0.743
# Epoch [10/30], Step [400/500], Loss: 0.6926
# Epoch [10/30], Step [500/500], Loss: 0.6867
# Epoch [11/30], Step [100/500], Loss: 0.6203
# Epoch [23/30], Step [100/500], Loss: 0.3485
# Epoch [23/30], Step [200/500], Loss: 0.5974
# Epoch [23/30], Step [300/500], Loss: 0.4933
# Epoch [23/30], Step [400/500], Loss: 0.3148
# Epoch [23/30], Step [500/500], Loss: 0.6378
# Epoch [24/30], Step [100/500], Loss: 0.3214
# Epoch [24/30], Step [200/500], Loss: 0.6125
# Epoch [24/30], Step [300/500], Loss: 0.5033
# Epoch [24/30], Step [400/500], Loss: 0.4553
# Epoch [24/30], Step [500/500], Loss: 0.6156
# Epoch [25/30], Step [100/500], Loss: 0.3327
# Epoch [25/30], Step [200/500], Loss: 0.3402
# Epoch [25/30], Step [300/500], Loss: 0.5997
# Epoch [25/30], Step [400/500], Loss: 0.4843
# Epoch [25/30], Step [500/500], Loss: 0.5692
# Epoch [26/30], Step [100/500], Loss: 0.3871
# Epoch [26/30], Step [200/500], Loss: 0.4732
# Epoch [26/30], Step [300/500], Loss: 0.4828
# Epoch [26/30], Step [400/500], Loss: 0.3149
# Epoch [26/30], Step [500/500], Loss: 0.4377
# Epoch [27/30], Step [100/500], Loss: 0.5159
# Epoch [27/30], Step [200/500], Loss: 0.3925
# Epoch [27/30], Step [300/500], Loss: 0.4181
# Epoch [27/30], Step [400/500], Loss: 0.4773
# Epoch [27/30], Step [500/500], Loss: 0.4454
# Epoch [28/30], Step [100/500], Loss: 0.3926
# Epoch [28/30], Step [200/500], Loss: 0.5067
# Epoch [28/30], Step [300/500], Loss: 0.3014
# Epoch [28/30], Step [400/500], Loss: 0.5537
# Epoch [28/30], Step [500/500], Loss: 0.3411
# Epoch [29/30], Step [100/500], Loss: 0.4436
# Epoch [29/30], Step [200/500], Loss: 0.2662
# Epoch [29/30], Step [300/500], Loss: 0.3835
# Epoch [29/30], Step [400/500], Loss: 0.3628
# Epoch [29/30], Step [500/500], Loss: 0.3146
# Epoch [30/30], Step [100/500], Loss: 0.437
# Epoch [30/30], Step [200/500], Loss: 0.4598
# Epoch [30/30], Step [300/500], Loss: 0.4283
# Epoch [30/30], Step [400/500], Loss: 0.4086
# Epoch [30/30], Step [500/500], Loss: 0.4689
#
# Time of training: 26.9 minutes

# %% [markdown]
# It is always interesting to see how fast the loss is changing its value. Let's check it :)

# %%
plt.figure(figsize=(13, 6))
plt.plot(losses)
plt.title("Losses", fontsize=20)
plt.show()

# %% [markdown]
# ## Let's test it!

# %%
validate_model(model, train_data)
# Out:
# Accuracy of the model on train data: 92.83%

# %%
validate_model(model, test_data)
# Out:
# Accuracy of the model on test data: 77.99%

# %% [markdown]
# #### So, accuracy is actually nice. On our train dataset an accuracy is mostly about 90% and on the test dataset is about 80%. Now, let's try to predict class by image

# %%
dataiter = iter(test_data)

# %%
images, labels = dataiter.next()
imshow(torchvision.utils.make_grid(images[:5]))

outputs = model(images)
_, predicted = torch.max(outputs.data, 1)
print("Actual classes:", " ".join('%5s' % classes[labels[j]] for j in range(5)))
print("Predicted classes:", " ".join('%5s' % classes[predicted[j]] for j in range(5)))
# Out:
# Actual classes:   cat  ship  ship plane  frog
# Predicted classes:   cat  ship  ship plane  frog

# %% [markdown]
# ## After some tests, i can surely say that model performs excellent results.

# %%
 def save_model(path):
    torch.save(model.state_dict(), path)
    print("Model saved!")
